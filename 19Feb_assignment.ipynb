# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a web framework, it’s a Python module that lets you develop web applications easily. It’s has a small and easy-to-extend core: it’s a microframework that doesn’t include an ORM (Object Relational Manager) or such features.
# <br>
# Advantages: <br>
# Integrated support for unit testing.
# RESTful request dispatching.
# Uses a Jinja2 template engine.
# It is based on Werkzeug toolkit.
# Support for secure cookies (client-side sessions).
# Extensive documentation.
# Google app engine compatibility.
# APIs are nicely shaped and coherent
# Easily deployable in production

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# from flask import Flask
# app = Flask(__name__)
#
# @app.route("/hello")
# def hello_world1():
#     return "<h1>Hello, World!</h1>"

# %% [markdown]
# ![helloWorld.png](attachment:d69f8c30-3906-4055-b07a-8168d0d0d5f1.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?
# <br>
# App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
# <br>
# App routing is used to map the specific URL with the associated function that is intended to perform some task. We can say that if we visit the particular URL mapped to some particular function, the output of that function is rendered on the browser's screen

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# <br>
# route to show the following details:
# <br>
# Company Name: ABC Corporation
# <br>
# Location: India
# <br>
# Contact Detail: 999-999-9999

# %% [markdown]
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/welcome")
# def welcome():
#     return "Welcome to ABC Corporation"
#
# @app.route("/")
# def company_details():
#     return """Company Name: ABC Corporation <br>
#             Location: India <br>
#             Contact Detail: 999-999-9999"""
#
# if __name__ == "__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# ![xyz.png](attachment:4ee04c2a-ae20-4c8c-afd4-32e0264bb61a.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# The url_for() function is used to build a URL to the specific function dynamically.

# %%
""" 
from flask import *  
   
app = Flask(__name__)  
  
@app.route('/admin')  
def admin():  
    return 'admin'  
  
@app.route('/librarion')  
def librarion():  
    return 'librarion'  
  
@app.route('/student')  
def student():  
    return 'student'  
  
@app.route('/user/<name>')  
def user(name):  
    if name == 'admin':  
        return redirect(url_for('admin'))  
    if name == 'librarion':  
        return redirect(url_for('librarion'))  
    if name == 'student':  
        return redirect(url_for('student'))  
if __name__ =='__main__':  
    app.run(host="0.0.0.0")  
"""
